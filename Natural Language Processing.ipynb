# %% [markdown]
# # Tokenization

# %%
import nltk
from nltk.tokenize import sent_tokenize,word_tokenize #tokenize sentiment and words

# %%
text="Augusta Ada King, Countess of Lovelace (née Byron; 10 December 1815 – 27 November 1852) was an English mathematician and writer, chiefly known for her work on Charles Babbage's proposed mechanical general-purpose computer, the Analytical Engine. She was the first to recognise that the machine had applications beyond pure calculation, and to have published the first"

# %%
text.split() #tokenize our text and split words
# Out:
# ['Augusta',
#  'Ada',
#  'King,',
#  'Countess',
#  'of',
#  'Lovelace',
#  '(née',
#  'Byron;',
#  '10',
#  'December',
#  '1815',
#  '–',
#  '27',
#  'November',
#  '1852)',
#  'was',
#  'an',
#  'English',
#  'mathematician',
#  'and',
#  'writer,',
#  'chiefly',
#  'known',
#  'for',
#  'her',
#  'work',
#  'on',
#  'Charles',
#  "Babbage's",
#  'proposed',
#  'mechanical',
#  'general-purpose',
#  'computer,',
#  'the',
#  'Analytical',
#  'Engine.',
#  'She',
#  'was',
#  'the',
#  'first',
#  'to',
#  'recognise',
#  'that',
#  'the',
#  'machine',
#  'had',
#  'applications',
#  'beyond',
#  'pure',
#  'calculation,',
#  'and',
#  'to',
#  'have',
#  'published',
#  'the',
#  'first']

# %%
word_tokenize(text )
# Out:
# ['Augusta',
#  'Ada',
#  'King',
#  ',',
#  'Countess',
#  'of',
#  'Lovelace',
#  '(',
#  'née',
#  'Byron',
#  ';',
#  '10',
#  'December',
#  '1815',
#  '–',
#  '27',
#  'November',
#  '1852',
#  ')',
#  'was',
#  'an',
#  'English',
#  'mathematician',
#  'and',
#  'writer',
#  ',',
#  'chiefly',
#  'known',
#  'for',
#  'her',
#  'work',
#  'on',
#  'Charles',
#  'Babbage',
#  "'s",
#  'proposed',
#  'mechanical',
#  'general-purpose',
#  'computer',
#  ',',
#  'the',
#  'Analytical',
#  'Engine',
#  '.',
#  'She',
#  'was',
#  'the',
#  'first',
#  'to',
#  'recognise',
#  'that',
#  'the',
#  'machine',
#  'had',
#  'applications',
#  'beyond',
#  'pure',
#  'calculation',
#  ',',
#  'and',
#  'to',
#  'have',
#  'published',
#  'the',
#  'first']

# %%
word_tokenize(text) #removes punctuation marks
# Out:
# ['Augusta',
#  'Ada',
#  'King',
#  ',',
#  'Countess',
#  'of',
#  'Lovelace',
#  '(',
#  'née',
#  'Byron',
#  ';',
#  '10',
#  'December',
#  '1815',
#  '–',
#  '27',
#  'November',
#  '1852',
#  ')',
#  'was',
#  'an',
#  'English',
#  'mathematician',
#  'and',
#  'writer',
#  ',',
#  'chiefly',
#  'known',
#  'for',
#  'her',
#  'work',
#  'on',
#  'Charles',
#  'Babbage',
#  "'s",
#  'proposed',
#  'mechanical',
#  'general-purpose',
#  'computer',
#  ',',
#  'the',
#  'Analytical',
#  'Engine',
#  '.',
#  'She',
#  'was',
#  'the',
#  'first',
#  'to',
#  'recognise',
#  'that',
#  'the',
#  'machine',
#  'had',
#  'applications',
#  'beyond',
#  'pure',
#  'calculation',
#  ',',
#  'and',
#  'to',
#  'have',
#  'published',
#  'the',
#  'first']

# %%
sent_tokenize(text) #tokenize phrases
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38c7400f0957> in <module>
# ----> 1 sent_tokenize(text) #tokenize phrases
#
# NameError: name 'sent_tokenize' is not defined

# %%
for token in word_tokenize(text):
    print(token) #write each token one by one

# %% [markdown]
# # Stop words
# are any word in a stop list (or stoplist or negative dictionary) which are filtered out (i.e. stopped) before or after processing of natural language data (text),they are useless data  for computer.Thresholds can be set to stopwords for the tutorial of the algorithm.

# %%
stopwords.words('english')

# %%
stopwords.words('spanish')
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
# ...

# %%
from nltk.corpus import stopwords #corpus is the language we use in natural language processing
from nltk.tokenize import word_tokenize

# %%
words=word_tokenize(text) #To trade in text, you must first tokenize it.

# %%
filtered_words=[]
for word in words:
    if word not in stopwords:
        filtered_words.append(word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-d34c34657bd9> in <module>
#       1 filtered_words=[]
#       2 for word in words:
# ----> 3     if word not in stopwords:
#       4         filtered_words.append(word)
#
# TypeError: argument of type 'WordListCorpusReader' is not iterable

# %%
filtered_words
# Out:
# []

# %% [markdown]
# # NLTK STEMMING
# .Stemming usually refers to a crude heuristic process that chops off the ends of words in the hope of achieving this goal correctly most of the time, and often includes the removal of derivational affixes.

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()

# %%
words=['drive','driving','driver','drives','drove','cats','children']

# %%
for w in words:
    print(ps.stem(w))
# Out:
# drive
# drive
# driver
# drive
# drove
# cat
# children

# %%
turkish=['children','childhood','childrens']

# %%
for w in turkish:
    print(ps.stem(w))
# Out:
# children
# childhood
# children

# %% [markdown]
# # Part of Speech Tagging
# In corpus linguistics, part-of-speech tagging, also called grammatical tagging is the process of marking up a word in a text (corpus) as corresponding to a particular part of speech, based on both its definition and its context. A simplified form of this is commonly taught to school-age children, in the identification of words as nouns, verbs, adjectives, adverbs, etc.

# %%
import nltk

# %%
alice='When Nietzsche Wept is a 1992 novel by Irvin D. Yalom, Emeritus Professor of Psychiatry at Stanford University, an existentialist, and psychotherapist.'

# %%
tokenized=nltk.word_tokenize(alice)

# %%
nltk.pos_tag(tokenized)
# Out:
# [('When', 'WRB'),
#  ('Nietzsche', 'NNP'),
#  ('Wept', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('1992', 'CD'),
#  ('novel', 'NN'),
#  ('by', 'IN'),
#  ('Irvin', 'NNP'),
#  ('D.', 'NNP'),
#  ('Yalom', 'NNP'),
#  (',', ','),
#  ('Emeritus', 'NNP'),
#  ('Professor', 'NNP'),
#  ('of', 'IN'),
#  ('Psychiatry', 'NNP'),
#  ('at', 'IN'),
#  ('Stanford', 'NNP'),
#  ('University', 'NNP'),
#  (',', ','),
#  ('an', 'DT'),
#  ('existentialist', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('psychotherapist', 'NN'),
#  ('.', '.')]

# %% [markdown]
# # Named Entity Recognition
# Named-entity recognition is a subtask of information extraction that seeks to locate and classify named entities mentioned in unstructured text into pre-defined categories such as person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc.

# %%
import nltk

# %%
test='Steven Paul Jobs was an American business magnate, industrial designer, media proprietor, and investor. He was the co-founder, chairman, and CEO of Apple the chairman and majority shareholder of Pixar a member of The Walt Disney Company s board of directors following its acquisition of Pixar; and the founder, chairman, and CEO of NeXT. He is widely recognized as a pioneer of the personal computer revolution of the 1970s and 1980s, along with his early business partner and fellow Apple co-founder Steve Wozniak.'

# %%
tokenized=nltk.word_tokenize(test)

# %%
tagged=nltk.pos_tag(tokenized)

# %%
named_ent=nltk.ne_chunk(tagged)

# %%
named_ent.draw()

# %% [markdown]
# # Lemmatization
# usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma . If confronted with the token saw, stemming might return just s, whereas lemmatization would attempt to return either see or saw depending on whether the use of the token was as a verb or a noun.

# %%
from nltk.stem import WordNetLemmatizer

# %%
lem=WordNetLemmatizer()

# %%
for w in words:
    print(lem.lemmatize(w)) #words=['drive','driving','driver','drives','drove','cats','children']
# Out:
# drive
# driving
# driver
# drive
# drove
# cat
# child

# %%
lem.lemmatize('drove','v')
# Out:
# 'drive'

# %%
For NLP Research use most common corpuses are : Kaggle,Project Gutenberg,Wikipedia Downloads,Common Crawl

# %% [markdown]
# # What is One Hot Encoding?
# A one hot encoding is a representation of categorical variables as binary vectors.
#
# This first requires that the categorical values be mapped to integer values.
#
# Then, each integer value is represented as a binary vector that is all zero values except the index of the integer, which is marked with a 1.A one hot encoding allows the representation of categorical data to be more expressive.
#
# Many machine learning algorithms cannot work with categorical data directly. The categories must be converted into numbers. This is required for both input and output variables that are categorical.

# %% [markdown]
# # WORD EMBEDDING
# Both word2vec and glove enable us to represent a word in the form of a vector (often called embedding). They are the two most popular algorithms for word embeddings that bring out the semantic similarity of words that captures different facets of the meaning of a word.
#
# Word2vec(unsupervised) embeddings are based on training a shallow feedforward neural network while glove embeddings are learnt based on matrix factorization techniques.The relationship between words is derived by cosine distance between words. Such word vectors are good at answering analogy questions. For instance,the distance between king and queen is about the same as that between man and woman.
#
# Glove model is based on leveraging global word to word co-occurance counts leveraging the entire corpus. Word2vec on the other hand leverages co-occurance within local context (neighbouring words).

# %% [markdown]
# # Continuous Bag of Words Model (CBOW) and Skip-gram
#
# ![image.png](attachment:image.png)
# In the CBOW model, the distributed representations of context (or surrounding words) are combined to predict the word in the middle. While in the Skip-gram model, the distributed representation of the input word is used to predict the context.
#
# Skip-gram Model:
#     Creating a “fake” task for the neural network to train. We won’t be interested in the inputs and outputs of this network, rather the goal is actually just to learn the weights of the hidden layer that are actually the “word vectors” that we’re trying to learn.(center word centered algorithm)
#
#     The dimensions of the input vector will be 1xV — where V is the number of words in the vocabulary
#
#
# CBOW :
# The fake task in CBOW is somewhat similar to Skip-gram, in the sense that we still take a pair of words and teach the model that they co-occur but instead of adding the errors we add the input words for the same target word.
#
#
# Skip-gram: works well with a small amount of the training data, represents well even rare words or phrases.
# CBOW: several times faster to train than the skip-gram, slightly better accuracy for the frequent words.
